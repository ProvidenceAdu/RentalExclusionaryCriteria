# %% [markdown]
# ### Import Libraries
#
#
#  - The os module allows us to interact with operating systems including changing working directory
#  - The pandas module allows us to read, clean and preprocess the output CSV files that were web scraped
#  - The glob module allows us to search through file paths and search for files that meet a specific pattern in this example we look for .csv patterns
#  - The bs4 module allows you to pull data from HTML document

# %%
import glob as gb
import pandas as pd 
import os
from bs4 import BeautifulSoup

# %% [markdown]
# ### Set Path
#  - Set your path to where CSV outputs of your zillow webscraping was exported to us the os chdir method

# %%
path = "C:\\Users\\padu\\Desktop\\Zillow\\Final\\InitialCraiglist"
os.chdir(path)

# %% [markdown]
# ### Get a list of all CSV outputs
# - Use the glob method get generate a list of all your output csv in your directory

# %%
All = gb.glob(path + "/*.csv")

# %% [markdown]
# ### Concatenate CSV
# - combine all files as a single CSV by concatenating them. To do this:
#     - loop through the list of CSV in your path and use the pandas.read_csv method to read them. It will create a generator
#     - Afterward use the pd.concat method to concatenate all your csv files

# %%
Craiglist = (pd.read_csv(file) for file in All)
Craiglist  = pd.concat(Craiglist, ignore_index=True)

# %%
Craiglist.shape
# Out:
# (217273, 13)

# %%
len(Craiglist)
# Out:
# 217273

# %%
Craiglist.columns
# Out:
# Index(['Post_datetime', 'Post Price', 'Post hood', 'Post title', 'PostURL',
#        'address', 'overview', 'bedroom_baths', 'Title', 'Price', 'Other',
#        'lat', 'lon'],
#       dtype='object')

# %%
Craiglist
# Out:
#            Post_datetime               Post Price  \
# 0       2021-03-15 13:47     $829\nimage 1 of 7<>
# 1       2021-03-15 13:47   $1,152\nimage 1 of 8<>
# 2       2021-03-15 13:45   $1,284\nimage 1 of 9<>
# 3       2021-03-15 13:45  $1,364\nimage 1 of 10<>
# 4       2021-03-15 13:43   $1,295\nimage 1 of 8<>
# ...                  ...                      ...
# 217268  2022-01-26 10:15                   $1,795
# 217269  2022-01-26 10:07                   $2,475
# 217270  2022-01-26 10:06                   $1,670
# 217271  2022-01-26 10:05                   $1,604
# 217272  2022-01-26 10:04                   $1,469
#
#                                                 Post hood  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3           <span class="result-hood"> (Charlotte)</span>
# 4                                                     NaN
# ...                                                   ...
# 217268  <span class="result-hood"> (Indian Trail  )</s...
# 217269  <span class="result-hood"> (4928 Old Pineville...
# 217270  <span class="result-hood"> (517 Pink Moon Driv...
# 217271  <span class="result-hood"> (Plaza Midwood  )</...
# 217272  <span class="result-hood"> (517 Pink Moon Driv...
#
#                                                Post title  \
# 0       <a class="result-title hdrlnk" data-id="729170...
# 1       <a class="result-title hdrlnk" data-id="729178...
# 2       <a class="result-title hdrlnk" data-id="729177...
# 3       <a class="result-title hdrlnk" data-id="729178...
# 4       <a class="result-title hdrlnk" data-id="729171...
# ...                                                   ...
# 217268                               Love Where You Live!
# 217269  Brand New -Dual Sinks, Spacious Closest, Prep ...
# 217270                Largest Two Bedrooms in Rock Hill!!
# 217271  Spacious One Bedroom With Courtyard Views in P...
# 217272  First Floor Apartment located in the Exclusive...
#
#                                                   PostURL  \
# 0       https://charlotte.craigslist.org/apa/d/charlot...
# 1       https://charlotte.craigslist.org/apa/d/concord...
# 2       https://charlotte.craigslist.org/apa/d/charlot...
# 3       https://charlotte.craigslist.org/apa/d/charlot...
# 4       https://charlotte.craigslist.org/apa/d/charlot...
# ...                                                   ...
# 217268  https://charlotte.craigslist.org/apa/d/matthew...
# 217269  https://charlotte.craigslist.org/apa/d/charlot...
# 217270  https://charlotte.craigslist.org/apa/d/fort-mi...
# 217271  https://charlotte.craigslist.org/apa/d/charlot...
# 217272  https://charlotte.craigslist.org/apa/d/fort-mi...
#
#                            address  \
# 0               8061 Woodscape Dr.
# 1           7850 Waterway Drive NW
# 2             11505 Masterton Road
# 3                 730 Hawthorne Ln
# 4       1825 Carrington Oaks Drive
# ...                            ...
# 217268            321 E. Park Road
# 217269       4928 Old Pineville Rd
# 217270         517 Pink Moon Drive
# 217271            808 Hawthorne Ln
# 217272         517 Pink Moon Drive
#
#                                                  overview bedroom_baths  \
# 0       <section id="postingbody">\n<div class="print-...     1BR / 1Ba
# 1       <section id="postingbody">\n<div class="print-...     1BR / 1Ba
# 2       <section id="postingbody">\n<div class="print-...     2BR / 2Ba
# 3       <section id="postingbody">\n<div class="print-...     1BR / 1Ba
# 4       <section id="postingbody">\n<div class="print-...     2BR / 2Ba
# ...                                                   ...           ...
# 217268  <section id="postingbody">\n<div class="print-...     3BR / 2Ba
# 217269  <section id="postingbody">\n<div class="print-...   3BR / 3.5Ba
# 217270  <section id="postingbody">\n<div class="print-...     2BR / 2Ba
# 217271  <section id="postingbody">\n<div class="print-...     1BR / 1Ba
# 217272  <section id="postingbody">\n<div class="print-...     1BR / 1Ba
#
#                                                     Title   Price  \
# 0       Great and spacious 1 bedroom 1 bath apartment!...    $829
# 1        Large Walk-in Closets, BBQ/Picnic Area, Dog Park  $1,152
# 2                        Playground, Tile Backsplash, Spa  $1,284
# 3       Key fob access, Uptown Charlotte views, 80 Wal...  $1,364
# 4       Ceiling Fans and Track Lighting, 9' Ceilings, ...  $1,295
# ...                                                   ...     ...
# 217268                               Love Where You Live!  $1,795
# 217269  Brand New -Dual Sinks, Spacious Closest, Prep ...  $2,475
# 217270                Largest Two Bedrooms in Rock Hill!!  $1,670
# 217271  Spacious One Bedroom With Courtyard Views in P...  $1,604
# 217272  First Floor Apartment located in the Exclusive...  $1,469
#
#                                                     Other        lat  \
# 0       <p class="attrgroup">\n<span class="shared-lin...        NaN
# 1       <p class="attrgroup">\n<span class="shared-lin...        NaN
# 2       <p class="attrgroup">\n<span class="shared-lin...        NaN
# 3       <p class="attrgroup">\n<span class="shared-lin...        NaN
# 4       <p class="attrgroup">\n<span class="shared-lin...        NaN
# ...                                                   ...        ...
# 217268  <p class="attrgroup">\n<span class="shared-lin...  35.077413
# 217269  <p class="attrgroup">\n<span class="shared-lin...  35.171400
# 217270  <p class="attrgroup">\n<span class="shared-lin...  34.973637
# 217271  <p class="attrgroup">\n<span class="shared-lin...  35.219935
# 217272  <p class="attrgroup">\n<span class="shared-lin...  34.974876
#
#               lon
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 217268 -80.672131
# 217269 -80.908400
# 217270 -80.978508
# 217271 -80.818782
# 217272 -80.978165
#
# [217273 rows x 13 columns]

# %% [markdown]
# ### Texting Cleaning
#
#    - In this step we undertake initial cleaning of the description text associated with each rental listing. :
#
#    - Because the description text is in html format, we use the html parser from beautifulsoup and the get_text() method to get the text
#
#    - After extracting the text, we strip off extra line, and replace all standard text contact information text with blank text

# %%
results = []

for row in Craiglist['overview']:
    
    Firstcleaning = BeautifulSoup(row,'html.parser').get_text().rstrip('\n\n').strip()
    Secondcleaning = Firstcleaning.replace('QR Code Link to This Post','').replace("show contact info",'')
    data = Secondcleaning.strip('\n\n\n\n\n').replace('Call:  show contact inf','')
    
    results.append(data)

# %%
otherinformation = []

for row in Craiglist['Other']:
    Firstcleaning = BeautifulSoup(row,'html.parser').get_text().rstrip('\n\n').strip()
    otherinformation.append(Firstcleaning)

# %% [markdown]
# - Not all posting add the neighborhood information, for those with neighborhood information
# - we strip off '()' from the neighborhood name, for those that are null, we keep them null

# %%
hood = []

for row in Craiglist['Post hood']:
    
    # Not all posting add the neighborhood information, for those with neighborhood information
    # we strip off '()' from the neighborhood name, for those that are null, we keep them null
    
    try:
        Firstcleaning = BeautifulSoup(row,'html.parser').get_text()
        Secondcleaning = Firstcleaning.strip(' (').strip(')')
        hood.append(Secondcleaning)  
    except:
        hood.append(row)

# %%
sqft
# Out:
# [['1BR / 1Ba', '650ft2', 'available mar 20'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '677ft2', 'available now'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '685ft2', 'available now'],
#  ['1BR / 1Ba', '850ft2'],
#  ['1BR / 1Ba', '685ft2', 'available apr 17'],
#  ['2BR / 2Ba', '934ft2', 'available may 7'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['1BR / 1Ba', '664ft2', 'available jun 25'],
#  ['3BR / 2Ba', '1600ft2', 'available now'],
#  ['2BR / 2Ba', '1005ft2', 'available now'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['1BR / 1Ba', '745ft2', 'available apr 15'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '850ft2'],
#  ['2BR / 1Ba', '1026ft2', 'available now'],
#  ['1BR / 1Ba', '639ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '704ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '934ft2'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '725ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '639ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1000ft2'],
#  ['2BR / 2Ba', '1000ft2'],
#  ['2BR / 2Ba', '1000ft2'],
#  ['2BR / 2Ba', '1000ft2'],
#  ['1BR / 1Ba', '736ft2', 'available apr 5'],
#  ['3BR / 2.5Ba', '1926ft2'],
#  ['2BR / 2Ba', '1018ft2', 'available now'],
#  ['1BR / 1Ba', '664ft2', 'available jun 25'],
#  ['2BR / 2Ba', '1095ft2', 'available now'],
#  ['1BR / 1Ba', '847ft2'],
#  ['1BR / 1Ba', '880ft2'],
#  ['1BR / 1Ba', '880ft2'],
#  ['3BR / 2Ba', '1420ft2'],
#  ['2BR / 1Ba', '826ft2', 'available now'],
#  ['1BR / 1Ba', '685ft2', 'available now'],
#  ['1BR / 1Ba', 'available now'],
#  ['2BR / 2Ba', '1192ft2'],
#  ['1BR / 1Ba', '777ft2', 'available mar 16'],
#  ['1BR / 1Ba', '480ft2', 'available apr 9'],
#  ['2BR / 2Ba', 'available mar 19'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['1BR / 1Ba', '685ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '800ft2'],
#  ['4BR / 4Ba', '1327ft2'],
#  ['3BR / 1Ba', '750ft2', 'available now'],
#  ['2BR / 1.5Ba', '900ft2'],
#  ['1BR / 1Ba', '740ft2', 'available now'],
#  ['4BR / 2.5Ba', '2244ft2'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '804ft2'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '650ft2', 'available now'],
#  ['2BR / 2Ba', '1013ft2', 'available apr 16'],
#  ['2BR / 2Ba', '960ft2', 'available mar 26'],
#  ['3BR / 2Ba', '1130ft2'],
#  ['1BR / 1Ba', 'available now'],
#  ['2BR / 2Ba', 'available mar 19'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['1BR / 1Ba', '685ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '800ft2'],
#  ['4BR / 4Ba', '1327ft2'],
#  ['3BR / 1Ba', '750ft2', 'available now'],
#  ['2BR / 1.5Ba', '900ft2'],
#  ['1BR / 1Ba', '740ft2', 'available now'],
#  ['4BR / 2.5Ba', '2244ft2'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '804ft2'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '650ft2', 'available now'],
#  ['2BR / 2Ba', '1013ft2', 'available apr 16'],
#  ['2BR / 2Ba', '960ft2', 'available mar 26'],
#  ['3BR / 2Ba', '1130ft2'],
#  ['1BR / 1Ba', 'available now'],
#  ['1BR / 1Ba', '756ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1024ft2'],
#  ['3BR / 2Ba', '1614ft2', 'available now'],
#  ['2BR / 2Ba', '1061ft2'],
#  ['2BR / 2Ba', '1024ft2'],
#  ['2BR / 2Ba', '1061ft2'],
#  ['2BR / 2Ba', '0917ft2', 'available apr 16'],
#  ['2BR / 2Ba', '1272ft2', 'available now'],
#  ['2BR / 2Ba', '917ft2', 'available apr 16'],
#  ['1BR / 1Ba', '826ft2', 'available now'],
#  ['3BR / 1Ba', '750ft2', 'available now'],
#  ['1BR / 1Ba', '704ft2', 'available now'],
#  ['1BR / 1Ba', '725ft2'],
#  ['2BR / 2Ba', '859ft2'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['1BR / 1Ba', '709ft2'],
#  ['2BR / 2Ba', '930ft2', 'available now'],
#  ['1BR / 1Ba', '748ft2', 'available now'],
#  ['3BR / 2Ba', '1727ft2', 'available now'],
#  ['2BR / 2Ba', '934ft2', 'available mar 17'],
#  ['1BR / 1Ba', 'available now'],
#  ['2BR / 1Ba', '1000ft2'],
#  ['1BR / 1Ba', '900ft2'],
#  ['1BR / 1Ba', '768ft2', 'available may 15'],
#  ['1BR / 1Ba', '680ft2', 'available apr 10'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['2BR / 1Ba', '875ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '767ft2', 'available apr 8'],
#  ['1BR / 1.5Ba', '870ft2', 'available apr 2'],
#  ['1BR / 1Ba', '704ft2', 'available now'],
#  ['2BR / 2Ba', '925ft2'],
#  ['1BR / 1.5Ba', '870ft2', 'available apr 2'],
#  ['1BR / 1Ba', '600ft2'],
#  ['2BR / 2Ba', '1104ft2', 'available now'],
#  ['2BR / 1Ba', '815ft2'],
#  ['1BR / 1Ba', '757ft2'],
#  ['1BR / 1Ba', '864ft2', 'available now'],
#  ['2BR / 2Ba', '1064ft2'],
#  ['1BR / 1Ba', '631ft2'],
#  ['5BR / 2.5Ba', 'available mar 20'],
#  ['1BR / 1Ba', '835ft2'],
#  ['1BR / 1Ba', '709ft2'],
#  ['1BR / 1Ba', '880ft2'],
#  ['1BR / 1Ba', '745ft2', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '656ft2', 'available mar 31'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 2Ba', '1044ft2', 'available mar 16'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 1Ba', '1026ft2', 'available now'],
#  ['2BR / 2Ba', '930ft2', 'available now'],
#  ['1BR / 1Ba', '750ft2', 'available apr 19'],
#  ['2BR / 1Ba', '837ft2', 'available apr 21'],
#  ['1BR / 1Ba', '750ft2', 'available now'],
#  ['1BR / 1.5Ba', '870ft2', 'available apr 2'],
#  ['1BR / 1Ba', '841ft2'],
#  ['1BR / 1Ba', '781ft2'],
#  ['3BR / 3Ba', '1298ft2', 'available now'],
#  ['1BR / 1Ba', '500ft2', 'available now'],
#  ['1BR / 1Ba', '750ft2', 'available apr 19'],
#  ['2BR / 1Ba', '837ft2', 'available apr 21'],
#  ['1BR / 1Ba', '750ft2', 'available now'],
#  ['1BR / 1.5Ba', '870ft2', 'available apr 2'],
#  ['1BR / 1Ba', '841ft2'],
#  ['1BR / 1Ba', '781ft2'],
#  ['3BR / 3Ba', '1298ft2', 'available now'],
#  ['1BR / 1Ba', '500ft2', 'available now'],
#  ['2BR / 2Ba', '1085ft2', 'available now'],
#  ['2BR / 2Ba', '1270ft2'],
#  ['1BR / 1Ba', '870ft2', 'available mar 22'],
#  ['2BR / 2Ba', '925ft2', 'available mar 31'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '750ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['2BR / 1Ba', 'available mar 31'],
#  ['1BR / 1Ba', '685ft2'],
#  ['2BR / 1Ba', 'available mar 31'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 1Ba', 'available mar 30'],
#  ['3BR / 2Ba', '1372ft2'],
#  ['3BR / 1Ba'],
#  ['1BR / 1Ba', '745ft2', 'available apr 7'],
#  ['2BR / 2.5Ba', '1181ft2', 'available mar 26'],
#  ['1BR / 1Ba', '936ft2', 'available now'],
#  ['2BR / 2Ba', '1006ft2', 'available now'],
#  ['2BR / 1Ba', '1026ft2', 'available now'],
#  ['1BR / 1Ba'],
#  ['1BR / 1Ba', '880ft2'],
#  ['3BR / 2Ba', '1298ft2', 'available now'],
#  ['2BR / 2Ba', '1085ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1085ft2', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '725ft2'],
#  ['2BR / 2Ba', '934ft2', 'available may 7'],
#  ['1BR / 1Ba', '300ft2', 'available now'],
#  ['2BR / 2Ba', '1085ft2', 'available now'],
#  ['1BR / 1Ba', '870ft2', 'available now'],
#  ['2BR / 2Ba', '1085ft2', 'available now'],
#  ['1BR / 1Ba', '847ft2', 'available now'],
#  ['2BR / 2Ba', '934ft2', 'available mar 17'],
#  ['3BR / 2Ba', '1286ft2', 'available mar 26'],
#  ['2BR / 2Ba', '1074ft2', 'available now'],
#  ['2BR / 2Ba', '960ft2', 'available mar 26'],
#  ['1BR / 1Ba', 'available now'],
#  ['1BR / 1Ba', '300ft2', 'available apr 9'],
#  ['1BR / 1.5Ba', '900ft2'],
#  ['1BR / 1Ba', '750ft2', 'available mar 26'],
#  ['2BR / 2Ba', '934ft2', 'available apr 13'],
#  ['2BR / 2Ba', '1000ft2'],
#  ['2BR / 2Ba', '1000ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2', 'available now'],
#  ['1BR / 1Ba', '725ft2'],
#  ['1BR / 1Ba', '880ft2'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['1BR / 1Ba', '700ft2', 'available now'],
#  ['2BR / 2Ba', '900ft2', 'available now'],
#  ['2BR / 1Ba', '1004ft2', 'available now'],
#  ['2BR / 2Ba', '1005ft2', 'available now'],
#  ['1BR / 1Ba', '231ft2', 'available now'],
#  ['1BR / 1Ba', '695ft2', 'available now'],
#  ['1BR / 1Ba', '725ft2'],
#  ['0BR / 1Ba'],
#  ['2BR / 2Ba', '1190ft2', 'available apr 15'],
#  ['3BR / 2Ba', 'available mar 18'],
#  ['3BR / 2Ba', '1200ft2', 'available now'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['1BR / 1Ba', '725ft2'],
#  ['2BR / 1Ba', '925ft2'],
#  ['1BR / 1Ba', '890ft2'],
#  ['2BR / 2Ba', '1005ft2', 'available now'],
#  ['2BR / 2Ba', '925ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '709ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '890ft2'],
#  ['1BR / 1Ba', '725ft2', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', 'available mar 18'],
#  ['3BR / 2Ba', '1200ft2', 'available now'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['1BR / 1Ba', '725ft2'],
#  ['2BR / 1Ba', '925ft2'],
#  ['1BR / 1Ba', '890ft2'],
#  ['2BR / 2Ba', '1005ft2', 'available now'],
#  ['2BR / 2Ba', '925ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '709ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '890ft2'],
#  ['1BR / 1Ba', '725ft2', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '890ft2'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '816ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 1Ba', '1000ft2', 'available mar 22'],
#  ['3BR / 2Ba', '1828ft2', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '890ft2'],
#  ['1BR / 1Ba', '815ft2', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 2Ba', '1160ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['1BR / 1Ba', '480ft2'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['4BR / 2.5Ba', '2400ft2', 'available apr 17'],
#  ['1BR / 1Ba', '725ft2'],
#  ['1BR / 1Ba', '850ft2'],
#  ['1BR / 1Ba', '709ft2'],
#  ['4BR / 2.5Ba', '2000ft2'],
#  ['3BR / 2Ba', '1405ft2', 'available now'],
#  ['2BR / 2Ba', '1100ft2', 'available may 1'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2', 'available apr 1'],
#  ['1BR / 1Ba', '910ft2', 'available now'],
#  ['1BR / 1Ba', '761ft2', 'available now'],
#  ['1BR / 1Ba', '684ft2', 'available now'],
#  ['2BR / 2Ba', '1162ft2', 'available now'],
#  ['3BR / 1.5Ba', '1140ft2', 'available mar 22'],
#  ['1BR / 1Ba', '785ft2'],
#  ['3BR / 1Ba', '750ft2', 'available now'],
#  ['3BR / 2Ba', '1422ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 2Ba', '1055ft2', 'available now'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['0BR / 1Ba', '400ft2', 'available apr 18'],
#  ['1BR / 1Ba', '660ft2', 'available now'],
#  ['0BR / 1Ba', '617ft2', 'available may 26'],
#  ['1BR / 1Ba', '725ft2'],
#  ['2BR / 2Ba', '1040ft2', 'available now'],
#  ['1BR / 1Ba', 'available now'],
#  ['1BR / 1Ba', '631ft2'],
#  ['1BR / 1Ba', '709ft2'],
#  ['2BR / 2Ba', 'available now'],
#  ['1BR / 1Ba', '845ft2', 'available now'],
#  ['1BR / 1Ba', '757ft2'],
#  ['2BR / 2Ba', '1064ft2'],
#  ['1BR / 1Ba', '480ft2'],
#  ['2BR / 1Ba', 'available now'],
#  ['2BR / 1Ba', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 2Ba', '991ft2'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['1BR / 1Ba', '745ft2', 'available now'],
#  ['1BR / 1Ba', '650ft2', 'available mar 22'],
#  ['1BR / 1Ba', '785ft2'],
#  ['3BR / 2Ba', '2108ft2', 'available apr 4'],
#  ['1BR / 1Ba', '650ft2', 'available now'],
#  ['1BR / 1Ba', '709ft2'],
#  ['1BR / 1Ba', '480ft2'],
#  ['2BR / 1Ba', 'available now'],
#  ['2BR / 1Ba', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 2Ba', '991ft2'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['1BR / 1Ba', '745ft2', 'available now'],
#  ['1BR / 1Ba', '650ft2', 'available mar 22'],
#  ['1BR / 1Ba', '785ft2'],
#  ['3BR / 2Ba', '2108ft2', 'available apr 4'],
#  ['1BR / 1Ba', '650ft2', 'available now'],
#  ['1BR / 1Ba', '709ft2'],
#  ['1BR / 1Ba', '850ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['3BR / 1Ba', '750ft2', 'available now'],
#  ['1BR / 1Ba', '890ft2'],
#  ['2BR / 2Ba', '930ft2', 'available now'],
#  ['1BR / 1Ba', '480ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '700ft2'],
#  ['2BR / 1Ba', '1110ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['1BR / 1Ba', '650ft2'],
#  ['1BR / 1Ba', '725ft2'],
#  ['1BR / 1Ba', '890ft2'],
#  ['2BR / 3.5Ba', 'available now'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 2Ba', '930ft2', 'available now'],
#  ['1BR / 1Ba', '890ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '709ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '685ft2', 'available now'],
#  ['1BR / 1Ba', '890ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '660ft2', 'available now'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 2Ba', '930ft2', 'available now'],
#  ['1BR / 1Ba', '890ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1630ft2', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 2Ba', '1005ft2', 'available now'],
#  ['1BR / 1Ba', '890ft2'],
#  ['3BR / 2Ba', '1460ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', 'available now'],
#  ['1BR / 1Ba', '850ft2'],
#  ['1BR / 1Ba', '695ft2', 'available now'],
#  ['1BR / 1Ba', '785ft2'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['2BR / 2Ba', '934ft2', 'available may 7'],
#  ['1BR / 1Ba', '650ft2', 'available mar 22'],
#  ['1BR / 1Ba', '685ft2', 'available apr 17'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '725ft2'],
#  ['1BR / 1Ba', '480ft2'],
#  ['1BR / 1Ba', '725ft2'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['2BR / 2Ba', '1091ft2', 'available now'],
#  ['2BR / 1Ba', '837ft2', 'available apr 21'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['2BR / 1Ba', '837ft2', 'available apr 17'],
#  ['1BR / 1Ba', '795ft2', 'available apr 12'],
#  ['1BR / 1Ba', '838ft2', 'available now'],
#  ['3BR / 1Ba', '750ft2', 'available now'],
#  ['2BR / 2Ba', '934ft2', 'available may 7'],
#  ['3BR / 2Ba', '1282ft2', 'available apr 17'],
#  ['3BR / 2Ba', '1316ft2', 'available now'],
#  ['2BR / 1.5Ba', '1035ft2'],
#  ['1BR / 1Ba', '790ft2', 'available apr 15'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['2BR / 2Ba', '1086ft2', 'available mar 31'],
#  ['1BR / 1Ba', '639ft2'],
#  ['2BR / 2Ba', '1076ft2', 'available now'],
#  ['2BR / 1.5Ba', '1154ft2', 'available may 10'],
#  ['2BR / 2Ba', '1076ft2', 'available now'],
#  ['2BR / 1Ba', '1250ft2', 'available now'],
#  ['1BR / 1Ba', '880ft2'],
#  ['1BR / 1Ba', '600ft2'],
#  ['1BR / 1Ba', '600ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1052ft2', 'available now'],
#  ['1BR / 1Ba', '650ft2', 'available mar 22'],
#  ['2BR / 2Ba', '1002ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '600ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1052ft2', 'available now'],
#  ['1BR / 1Ba', '650ft2', 'available mar 22'],
#  ['2BR / 2Ba', '1002ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '794ft2', 'available now'],
#  ['3BR / 2Ba', '1405ft2', 'available now'],
#  ['1BR / 1Ba', 'available now'],
#  ['3BR / 2Ba', '1422ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2', 'available apr 1'],
#  ['2BR / 2Ba', '885ft2'],
#  ['2BR / 2Ba', '1076ft2', 'available now'],
#  ['2BR / 2Ba', '1071ft2', 'available may 12'],
#  ['1BR / 1Ba', '785ft2'],
#  ['2BR / 2Ba', '991ft2'],
#  ['1BR / 1Ba', '684ft2', 'available now'],
#  ['2BR / 2Ba', '1091ft2', 'available now'],
#  ['1BR / 1Ba', '850ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '480ft2', 'available apr 9'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1000ft2', 'available apr 1'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '951ft2', 'available now'],
#  ['2BR / 2Ba', '1044ft2', 'available apr 13'],
#  ['2BR / 2Ba', '1000ft2', 'available apr 1'],
#  ['3BR / 2Ba', '1282ft2', 'available apr 17'],
#  ['1BR / 1Ba', '745ft2', 'available now'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['2BR / 2Ba', '934ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1044ft2'],
#  ['2BR / 2Ba', '1137ft2', 'available now'],
#  ['1BR / 1Ba', '480ft2'],
#  ['2BR / 1.5Ba', '900ft2'],
#  ['2BR / 2Ba', '1044ft2', 'available may 29'],
#  ['1BR / 1Ba', '880ft2'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['2BR / 2Ba', 'available now'],
#  ['1BR / 1Ba', '725ft2'],
#  ['2BR / 2Ba', 'available now'],
#  ['2BR / 2Ba', '1079ft2', 'available now'],
#  ['2BR / 2Ba', '1137ft2', 'available now'],
#  ['2BR / 1Ba', '1071ft2', 'available apr 23'],
#  ['1BR / 1Ba', '600ft2'],
#  ['1BR / 1Ba', '848ft2'],
#  ['1BR / 1Ba', '745ft2', 'available now'],
#  ['1BR / 1Ba', '745ft2', 'available now'],
#  ['1BR / 1Ba', '745ft2', 'available now'],
#  ['1BR / 1Ba', '745ft2', 'available apr 1'],
#  ['2BR / 2Ba', '1000ft2', 'available apr 21'],
#  ['1BR / 1Ba', '781ft2'],
#  ['1BR / 1Ba', '841ft2'],
#  ['1BR / 1Ba', '781ft2'],
#  ['1BR / 1Ba', '781ft2'],
#  ['1BR / 1Ba', '740ft2', 'available now'],
#  ['2BR / 2Ba', '1125ft2', 'available apr 1'],
#  ['1BR / 1Ba', 'available now'],
#  ['2BR / 2Ba', '1124ft2', 'available now'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '480ft2'],
#  ['1BR / 1Ba', '709ft2'],
#  ['0BR / 1Ba', '617ft2', 'available may 26'],
#  ['2BR / 2Ba', '1184ft2', 'available now'],
#  ['1BR / 1Ba', '680ft2', 'available apr 15'],
#  ['1BR / 1Ba', '721ft2', 'available now'],
#  ['1BR / 1Ba', 'available now'],
#  ['2BR / 2Ba', '1044ft2', 'available now'],
#  ['2BR / 2Ba', '1022ft2', 'available now'],
#  ['2BR / 2Ba', '951ft2', 'available now'],
#  ['1BR / 1Ba', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '650ft2', 'available mar 20'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '958ft2', 'available now'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '958ft2', 'available now'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '704ft2', 'available now'],
#  ['2BR / 2Ba', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1198ft2'],
#  ['1BR / 1Ba', '750ft2', 'available mar 19'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '795ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 1.5Ba', '1154ft2', 'available apr 30'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '768ft2', 'available apr 8'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '959ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', 'available now'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['1BR / 1Ba', '740ft2', 'available now'],
#  ['2BR / 2Ba', '1044ft2'],
#  ['1BR / 1Ba', '777ft2', 'available mar 16'],
#  ['1BR / 1Ba', '890ft2', 'available now'],
#  ['5BR / 3.5Ba', '3627ft2', 'available apr 1'],
#  ['1BR / 1Ba', '870ft2', 'available now'],
#  ['3BR / 2.5Ba', '1800ft2', 'available now'],
#  ['3BR / 2.5Ba', '1800ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1000ft2', 'available apr 1'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '870ft2'],
#  ['2BR / 2Ba', '960ft2', 'available now'],
#  ['3BR / 2Ba', '1274ft2', 'available now'],
#  ['2BR / 2Ba', '1040ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2'],
#  ['1BR / 1Ba', '710ft2', 'available mar 19'],
#  ['1BR / 1Ba', '530ft2', 'available apr 30'],
#  ['1BR / 1Ba', '700ft2', 'available now'],
#  ['2BR / 2Ba', '900ft2', 'available now'],
#  ['1BR / 1Ba', '936ft2', 'available mar 19'],
#  ['3BR / 1Ba', '750ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2', 'available now'],
#  ['2BR / 2Ba', '1100ft2', 'available now'],
#  ['1BR / 1Ba', '725ft2'],
#  ['1BR / 1Ba', '235ft2', 'available now'],
#  ['1BR / 1Ba', '231ft2', 'available now'],
#  ['2BR / 1Ba', 'available jun 1'],
#  ['3BR / 2Ba', 'available apr 1'],
#  ['1BR / 1Ba', '890ft2'],
#  ['1BR / 1Ba', '910ft2', 'available now'],
#  ['1BR / 1Ba', '880ft2'],
#  ['1BR / 1Ba', '680ft2', 'available apr 15'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '725ft2'],
#  ['1BR / 1Ba', '890ft2'],
#  ['2BR / 2Ba', '934ft2', 'available may 7'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '934ft2', 'available now'],
#  ['1BR / 1Ba', '680ft2', 'available apr 15'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '725ft2'],
#  ['1BR / 1Ba', '890ft2'],
#  ['2BR / 2Ba', '934ft2', 'available may 7'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '934ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '934ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '934ft2', 'available may 7'],
#  ['2BR / 2Ba', '934ft2', 'available mar 17'],
#  ['2BR / 2Ba', '1000ft2', 'available apr 1'],
#  ['1BR / 1Ba', '835ft2'],
#  ['1BR / 1Ba', '650ft2'],
#  ['1BR / 1.5Ba', '780ft2'],
#  ['1BR / 1.5Ba', '780ft2'],
#  ['2BR / 2Ba', '934ft2', 'available mar 17'],
#  ['1BR / 1Ba', '709ft2'],
#  ['1BR / 1Ba', '639ft2'],
#  ['2BR / 2Ba', '902ft2'],
#  ['1BR / 1Ba', '600ft2', 'available apr 1'],
#  ['2BR / 2Ba', '1156ft2'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['1BR / 1Ba', '757ft2'],
#  ['1BR / 1Ba', '631ft2'],
#  ['2BR / 2Ba', '1064ft2'],
#  ['1BR / 1Ba', '757ft2'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['3BR / 2Ba', '1479ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1055ft2', 'available now'],
#  ['1BR / 1Ba', '740ft2'],
#  ['3BR / 2Ba', '1460ft2'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['2BR / 2Ba', '1081ft2'],
#  ['1BR / 1Ba', 'available now'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['2BR / 2Ba', '1071ft2', 'available apr 8'],
#  ['3BR / 2Ba', '1380ft2', 'available now'],
#  ['3BR / 2Ba', '1460ft2'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['2BR / 1Ba', '884ft2'],
#  ['1BR / 1Ba', '750ft2', 'available now'],
#  ['1BR / 1Ba', '847ft2'],
#  ['2BR / 2Ba', '1024ft2'],
#  ['2BR / 2Ba', '1044ft2', 'available may 13'],
#  ['2BR / 2.5Ba', '1235ft2'],
#  ['2BR / 1Ba'],
#  ['2BR / 1Ba', '1071ft2', 'available apr 20'],
#  ['2BR / 2Ba', '925ft2'],
#  ['1BR / 1Ba', '600ft2'],
#  ['1BR / 1Ba', '711ft2', 'available mar 16'],
#  ['2BR / 1Ba', 'available apr 7'],
#  ['1BR / 1Ba', '650ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1076ft2', 'available now'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 1Ba', '837ft2', 'available apr 17'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '870ft2'],
#  ['1BR / 1Ba', '870ft2'],
#  ['1BR / 1Ba', '870ft2'],
#  ['1BR / 1Ba', '870ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1044ft2', 'available mar 20'],
#  ['2BR / 2Ba', '951ft2', 'available now'],
#  ['3BR / 3Ba', '1360ft2', 'available now'],
#  ['1BR / 1Ba', '756ft2', 'available now'],
#  ['2BR / 2Ba', '1022ft2', 'available now'],
#  ['3BR / 3Ba', '1360ft2', 'available now'],
#  ['1BR / 1Ba', '870ft2'],
#  ['1BR / 1Ba', '870ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['1BR / 1Ba', '795ft2', 'available mar 31'],
#  ['1BR / 1Ba', '709ft2'],
#  ['2BR / 2Ba', '1137ft2', 'available now'],
#  ['1BR / 1Ba', '480ft2'],
#  ['2BR / 2Ba', '1137ft2', 'available now'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['1BR / 1Ba', '880ft2'],
#  ['3BR / 1Ba', '750ft2', 'available now'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['1BR / 1Ba', '880ft2'],
#  ['3BR / 1Ba', '750ft2', 'available now'],
#  ['2BR / 1Ba', '837ft2', 'available apr 17'],
#  ['2BR / 2Ba', '1235ft2'],
#  ['2BR / 2Ba', '1024ft2'],
#  ['2BR / 2.5Ba', '1235ft2'],
#  ['2BR / 2.5Ba', '1235ft2'],
#  ['3BR / 2Ba', '1405ft2', 'available now'],
#  ['1BR / 1Ba', '480ft2'],
#  ['1BR / 1Ba', '1000ft2', 'available apr 9'],
#  ['1BR / 1Ba', '880ft2'],
#  ['1BR / 1Ba', '745ft2', 'available now'],
#  ['2BR / 2Ba', '934ft2', 'available mar 17'],
#  ['1BR / 1Ba', '880ft2'],
#  ['1BR / 1Ba', '880ft2'],
#  ['1BR / 1Ba', '704ft2', 'available now'],
#  ['2BR / 2Ba', '1184ft2', 'available now'],
#  ['1BR / 1Ba', '704ft2', 'available now'],
#  ['2BR / 1Ba', '945ft2'],
#  ['4BR / 3Ba'],
#  ['3BR / 2Ba', '1460ft2'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['1BR / 1Ba', '880ft2'],
#  ['2BR / 2Ba', '958ft2', 'available now'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['2BR / 2Ba', '1000ft2', 'available apr 1'],
#  ['2BR / 2Ba', '1193ft2', 'available now'],
#  ['2BR / 2Ba', '930ft2', 'available now'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['1BR / 1Ba', '880ft2'],
#  ['1BR / 1Ba', '800ft2', 'available now'],
#  ['1BR / 1Ba', '880ft2'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['1BR / 1Ba', '835ft2'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['2BR / 2Ba', '1157ft2', 'available now'],
#  ['1BR / 1Ba', '777ft2', 'available now'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['3BR / 2Ba', '1422ft2', 'available now'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['1BR / 1Ba', '880ft2'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['2BR / 1.5Ba', '900ft2'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['2BR / 1Ba', '1026ft2', 'available now'],
#  ['1BR / 1Ba', '664ft2', 'available jun 25'],
#  ['2BR / 1Ba', '945ft2'],
#  ['4BR / 4.5Ba', '1674ft2'],
#  ['1BR / 1Ba', '600ft2'],
#  ['2BR / 2Ba', '1000ft2', 'available apr 1'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '768ft2', 'available may 15'],
#  ['1BR / 1Ba', '760ft2'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['2BR / 2Ba', '930ft2', 'available now'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '740ft2', 'available now'],
#  ['1BR / 1Ba', '480ft2'],
#  ['2BR / 2Ba'],
#  ['1BR / 1Ba'],
#  ['2BR / 2Ba'],
#  ['2BR / 2Ba', '991ft2'],
#  ['2BR / 2Ba', '1137ft2', 'available now'],
#  ['2BR / 2Ba', '1085ft2', 'available now'],
#  ['2BR / 1Ba', '826ft2', 'available now'],
#  ['2BR / 2Ba', '1095ft2', 'available now'],
#  ['1BR / 1Ba', '721ft2', 'available now'],
#  ['1BR / 1Ba', '850ft2'],
#  ['1BR / 1Ba', '685ft2'],
#  ['3BR / 2Ba', '1614ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '695ft2', 'available now'],
#  ['2BR / 2Ba', '1162ft2', 'available now'],
#  ['1BR / 1Ba', '826ft2', 'available now'],
#  ['2BR / 2Ba', '934ft2', 'available may 7'],
#  ['3BR / 2Ba', '1614ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['1BR / 1Ba', '695ft2', 'available now'],
#  ['2BR / 2Ba', '1162ft2', 'available now'],
#  ['1BR / 1Ba', '826ft2', 'available now'],
#  ['2BR / 2Ba', '934ft2', 'available may 7'],
#  ['1BR / 1Ba', '664ft2', 'available jun 25'],
#  ['1BR / 1Ba', '777ft2', 'available mar 16'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['4BR / 4Ba', '1327ft2'],
#  ['1BR / 1.5Ba', '870ft2', 'available apr 9'],
#  ['1BR / 1Ba', '664ft2', 'available jun 25'],
#  ['2BR / 1Ba', '1026ft2', 'available now'],
#  ['1BR / 1Ba', '790ft2', 'available now'],
#  ['1BR / 1.5Ba', '870ft2', 'available apr 9'],
#  ['3BR / 2Ba', '1460ft2'],
#  ['1BR / 1Ba', '835ft2'],
#  ['1BR / 1Ba', '781ft2'],
#  ['2BR / 2Ba', '1190ft2'],
#  ['1BR / 1Ba', '650ft2', 'available mar 20'],
#  ['3BR / 2Ba', '1443ft2', 'available mar 17'],
#  ['1BR / 1Ba', '656ft2', 'available mar 31'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['2BR / 2Ba', '1076ft2', 'available now'],
#  ['1BR / 1Ba', '880ft2'],
#  ['1BR / 1Ba', 'available now'],
#  ['1BR / 1Ba', '756ft2', 'available now'],
#  ['3BR / 2Ba', '1282ft2', 'available apr 17'],
#  ['1BR / 1Ba', '710ft2', 'available mar 19'],
#  ['1BR / 1Ba', '936ft2', 'available now'],
#  ['3BR / 2Ba', '1479ft2'],
#  ['2BR / 2Ba', '1091ft2', 'available now'],
#  ['3BR / 2Ba', '1460ft2'],
#  ['2BR / 2Ba', '925ft2'],
#  ['2BR / 2Ba', '917ft2', 'available apr 15'],
#  ['1BR / 1Ba', '748ft2', 'available now'],
#  ['1BR / 1Ba', '772ft2', 'available now'],
#  ['1BR / 1Ba', '745ft2', 'available apr 7'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['1BR / 1Ba', '880ft2'],
#  ['1BR / 1Ba', '795ft2', 'available now'],
#  ['2BR / 2Ba', '925ft2'],
#  ['1BR / 1Ba', '709ft2'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['1BR / 1.5Ba', '780ft2'],
#  ['1BR / 1.5Ba', '881ft2', 'available apr 23'],
#  ['1BR / 1.5Ba', '881ft2', 'available apr 23'],
#  ['2BR / 2Ba', '1064ft2'],
#  ['2BR / 2Ba', '1064ft2'],
#  ['2BR / 2Ba', '925ft2'],
#  ['2BR / 2Ba', '934ft2', 'available now'],
#  ['1BR / 1Ba', '757ft2'],
#  ['1BR / 1.5Ba', '881ft2', 'available apr 23'],
#  ['1BR / 1Ba', '600ft2'],
#  ['1BR / 1Ba', '631ft2'],
#  ['1BR / 1Ba', '758ft2'],
#  ['2BR / 2Ba', '925ft2'],
#  ['2BR / 2.5Ba', '1235ft2'],
#  ['1BR / 1.5Ba', '780ft2'],
#  ['1BR / 1Ba', '709ft2'],
#  ['1BR / 1Ba', '704ft2', 'available now'],
#  ['2BR / 2Ba', '991ft2'],
#  ['2BR / 2Ba', '1044ft2', 'available mar 20'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['3BR / 2Ba', '1200ft2'],
#  ['2BR / 2Ba', '1024ft2'],
#  ['2BR / 2Ba', '859ft2'],
#  ['2BR / 1Ba'],
#  ['1BR / 1Ba', '704ft2', 'available now'],
#  ['1BR / 1Ba', '750ft2', 'available now'],
#  ['1BR / 1.5Ba', '780ft2'],
#  ['3BR / 2Ba', '1200ft2'],
#  ['2BR / 1.5Ba', '975ft2', 'available mar 19'],
#  ['2BR / 1.5Ba', '975ft2', 'available mar 19'],
#  ['1BR / 1Ba', '799ft2'],
#  ['2BR / 1.5Ba', '975ft2', 'available mar 19'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['2BR / 1.5Ba', '975ft2', 'available mar 19'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1.5Ba', '780ft2'],
#  ['2BR / 2Ba', '1024ft2'],
#  ['2BR / 2Ba', '859ft2'],
#  ['2BR / 1Ba'],
#  ['1BR / 1Ba', '704ft2', 'available now'],
#  ['1BR / 1Ba', '750ft2', 'available now'],
#  ['1BR / 1.5Ba', '780ft2'],
#  ['3BR / 2Ba', '1200ft2'],
#  ['2BR / 1.5Ba', '975ft2', 'available mar 19'],
#  ['2BR / 1.5Ba', '975ft2', 'available mar 19'],
#  ['1BR / 1Ba', '799ft2'],
#  ['2BR / 1.5Ba', '975ft2', 'available mar 19'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['2BR / 1.5Ba', '975ft2', 'available mar 19'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1.5Ba', '780ft2'],
#  ['2BR / 1.5Ba', 'available apr 30'],
#  ['3BR / 2Ba', '1186ft2', 'available now'],
#  ['2BR / 2.5Ba', '1154ft2', 'available may 10'],
#  ['2BR / 2Ba', '1013ft2', 'available may 12'],
#  ['2BR / 1Ba'],
#  ['2BR / 1Ba'],
#  ['1BR / 1Ba', '777ft2', 'available mar 16'],
#  ['2BR / 2Ba', '1257ft2'],
#  ['2BR / 2Ba', '883ft2', 'available now'],
#  ['1BR / 1Ba', '750ft2', 'available mar 16'],
#  ['1BR / 1Ba', 'available now'],
#  ['2BR / 2Ba', '1186ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '670ft2', 'available may 11'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['3BR / 2Ba', '1286ft2', 'available mar 26'],
#  ['2BR / 2Ba', '960ft2', 'available mar 26'],
#  ['1BR / 1Ba', '750ft2', 'available mar 26'],
#  ['2BR / 2Ba', '925ft2'],
#  ['2BR / 1Ba', '935ft2', 'available now'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '934ft2', 'available apr 13'],
#  ['3BR / 2Ba', '1460ft2'],
#  ['2BR / 2Ba', '934ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['2BR / 2Ba', '934ft2', 'available may 10'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1460ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['1BR / 1Ba', '680ft2', 'available apr 15'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['2BR / 1Ba', '837ft2', 'available apr 17'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '934ft2', 'available may 7'],
#  ['1BR / 1Ba', '680ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '934ft2', 'available may 7'],
#  ['2BR / 2Ba', 'available now'],
#  ['1BR / 1Ba', '685ft2'],
#  ['2BR / 1Ba', '837ft2', 'available apr 21'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['1BR / 1Ba', '680ft2', 'available apr 23'],
#  ['2BR / 1Ba', '525ft2', 'available now'],
#  ['2BR / 1.5Ba', '900ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '847ft2'],
#  ['2BR / 2Ba', '934ft2', 'available mar 17'],
#  ['5BR / 3Ba'],
#  ['1BR / 1Ba', '480ft2'],
#  ['1BR / 1Ba', '685ft2', 'available apr 17'],
#  ['1BR / 1Ba', '680ft2'],
#  ['2BR / 1Ba', '837ft2', 'available mar 17'],
#  ['1BR / 1Ba', '639ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1055ft2', 'available now'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['1BR / 1Ba', '740ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '902ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['1BR / 1Ba', '480ft2'],
#  ['1BR / 1Ba', '710ft2', 'available now'],
#  ['2BR / 2.5Ba', '1318ft2', 'available now'],
#  ['2BR / 2Ba', '934ft2', 'available mar 17'],
#  ['1BR / 1Ba', '777ft2', 'available now'],
#  ['1BR / 1Ba', '835ft2'],
#  ['1BR / 1Ba', '757ft2'],
#  ['2BR / 2Ba', '1064ft2'],
#  ['1BR / 1Ba', '757ft2'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 1Ba', '750ft2', 'available now'],
#  ['1BR / 1Ba', '744ft2', 'available now'],
#  ['2BR / 1Ba', '935ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2', 'available apr 1'],
#  ['3BR / 2Ba', '1282ft2', 'available now'],
#  ['1BR / 1Ba', '744ft2', 'available now'],
#  ['2BR / 1Ba', '935ft2', 'available now'],
#  ['2BR / 2Ba', '1000ft2', 'available apr 1'],
#  ['3BR / 2Ba', '1282ft2', 'available now'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['2BR / 1Ba', '1026ft2', 'available now'],
#  ['0BR / 1Ba', '590ft2', 'available now'],
#  ['2BR / 2Ba'],
#  ['2BR / 2Ba', '1071ft2', 'available apr 14'],
#  ['2BR / 2Ba', '1095ft2', 'available now'],
#  ['1BR / 1Ba', '773ft2'],
#  ['1BR / 1Ba', '850ft2'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['2BR / 2Ba', '1081ft2'],
#  ['1BR / 1Ba', '785ft2'],
#  ['3BR / 2Ba', '1460ft2'],
#  ['3BR / 2Ba', '1479ft2'],
#  ['1BR / 1Ba', '600ft2'],
#  ['2BR / 2Ba', '934ft2', 'available mar 17'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['1BR / 1Ba', '700ft2', 'available apr 1'],
#  ['1BR / 1Ba', '800ft2'],
#  ['3BR / 2Ba', '1380ft2', 'available now'],
#  ['1BR / 1Ba', '880ft2'],
#  ['4BR / 4.5Ba', '1674ft2'],
#  ['1BR / 1Ba', '650ft2', 'available mar 22'],
#  ['3BR / 2Ba', '1381ft2'],
#  ['3BR / 2Ba', '1405ft2', 'available now'],
#  ['2BR / 1Ba', '935ft2', 'available now'],
#  ['2BR / 2Ba', '1076ft2', 'available now'],
#  ['1BR / 1Ba', '880ft2'],
#  ['3BR / 2Ba', '117100ft2', 'available now'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['2BR / 2Ba', '1177ft2'],
#  ['1BR / 1Ba', '650ft2', 'available mar 22'],
#  ['2BR / 2Ba', '1309ft2'],
#  ['2BR / 2Ba', '902ft2'],
#  ['2BR / 2Ba'],
#  ['2BR / 2Ba', '1024ft2'],
#  ['2BR / 2Ba', '1242ft2'],
#  ['3BR / 2Ba', '1265ft2', 'available now'],
#  ['1BR / 1Ba', '771ft2'],
#  ...]

# %%
# The floor size for each listing is in the 'other information' for example ['1BR / 1Ba', '650ft2', 'available mar 20']
# The 'other information' contains bathroom, bedrooms, floor size and available date for each listings
# This data is separated by '\n', hence we split them by '\n' and append them to a list


sqft = []

for row in otherinformation:
    split = row.split("\n")
    sqft.append(split)

    
# We check the length of the list to verifty if it's equal to 3 or equal 2: for example 
# When the length is 3 here is how the list loooks like for example: ['1BR / 1Ba', '650ft2', 'available mar 20']
# When the length is 2 here is how the list loooks like for example:  ['2BR / 2Ba', '1242ft2'],
# if the length is either (2 or 3) we append the second element of the list which is the floor size
# if the length is neither 2 or 3, then means there's no floor size information, hence we append zero for floorsize 
# for listings that meet this condition but doesn't have the floor size, we clean them in a later step
# Lastly, we use a list comprehension to replace the symbol 'ft2' with a blank space
    
floorsize = []

for row in sqft:
    if len(row) == 3 or len(row) == 2:
        floorsize.append(row[1])
    else:
        floorsize.append(str(0))

floorsizes = [text.replace("ft2","") for text in floorsize]

# %%
# Verify the length of the data

len(Craiglist), len(results), len(otherinformation),len(floorsizes)
# Out:
# (201023, 201023, 201023, 201023)

# %% [markdown]
# ### Add the Clean data to the original data frame

# %%
Craiglist['OverviewClean'] = results
Craiglist['Otherinformation'] = otherinformation
Craiglist['Neighborood'] = hood
Craiglist['floorsize'] = floorsizes

# %%
Craiglist.columns
# Out:
# Index(['Post_datetime', 'Post Price', 'Post hood', 'Post title', 'PostURL',
#        'address', 'overview', 'bedroom_baths', 'Title', 'Price', 'Other',
#        'lat', 'lon', 'OverviewClean', 'Otherinformation', 'Neighborood',
#        'floorsize'],
#       dtype='object')

# %% [markdown]
# ### Delete old columns in the dataframe

# %%
columns = [ 'Post_datetime','Post Price', 'Post hood', 'Post title', 'overview','Otherinformation','Other']

# %%
Craiglist = Craiglist.drop(columns,axis =1)

# %% [markdown]
# ### Check for duplicates
# - Because we are web scraping daily, there multiple duplicates in our data, we check for those using the duplicated method and the sum method
# - We can identify the unique listings by subracting the duplicated listings from all lisitings

# %%
Craiglist.duplicated().sum()
# Out:
# 156399

# %%
int(Craiglist.shape[0]) - Craiglist.duplicated().sum()
# Out:
# 44624

# %% [markdown]
# ### Generate Unique Listings
# - Create a variable that stores the unique listings

# %%
FinalCragilist = Craiglist.drop_duplicates()

# %%
len(FinalCragilist)
# Out:
# 44624

# %%
StreetAddress =  Craiglist.drop_duplicates(subset = "address")

# %%
len(StreetAddress)

# %% [markdown]
# ### Change directory for  Output file
#  -  Change the output directory for your final CSV
#  -  Since the cleaning including concatenating will be done multiple time for any addtional webscraping, you would have to export the final clean file to a different folder

# %%
path = "C:\\Users\\padu\\Desktop\\Zillow\\Final\\FinalCraiglist"
os.chdir(path)

# %% [markdown]
# ### Export the final output as a CSV file

# %%
FinalCragilist = Craiglist.drop_duplicates()

# %%
FinalCragilist.to_csv("FinalCraiglistDate.csv", index=False)
